# %% [markdown]
# ## Observations and Insights

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
merge_data = pd.merge(mouse_metadata,study_results,on="Mouse ID")
# Display the data table for preview
merge_data.head(10)
# Out:
#   Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0     k403     Ramicane  Male          21          16          0
# 1     k403     Ramicane  Male          21          16          5
# 2     k403     Ramicane  Male          21          16         10
# 3     k403     Ramicane  Male          21          16         15
# 4     k403     Ramicane  Male          21          16         20
# 5     k403     Ramicane  Male          21          16         25
# 6     k403     Ramicane  Male          21          16         30
# 7     k403     Ramicane  Male          21          16         35
# 8     k403     Ramicane  Male          21          16         40
# 9     k403     Ramicane  Male          21          16         45
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           45.000000                 0
# 1           38.825898                 0
# 2           35.014271                 1
# 3           34.223992                 1
# 4           32.997729                 1
# ...

# %%
# Checking the number of mice.
count_mice = merge_data["Mouse ID"].nunique()
count_mice
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
duplicated_mice = merge_data.loc[merge_data.duplicated(["Mouse ID", "Timepoint"])]

duplicated_mice["Mouse ID"].unique()
# Out:
# array(['g989'], dtype=object)

# %%
# Optional: Get all the data for the duplicate mouse ID. 

duplicated_mice
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 909     g989     Propriva  Female          21          26          0
# 911     g989     Propriva  Female          21          26          5
# 913     g989     Propriva  Female          21          26         10
# 915     g989     Propriva  Female          21          26         15
# 917     g989     Propriva  Female          21          26         20
#
#      Tumor Volume (mm3)  Metastatic Sites
# 909           45.000000                 0
# 911           47.570392                 0
# 913           49.880528                 0
# 915           53.442020                 0
# 917           54.657650                 1

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_data= merge_data.loc[merge_data["Mouse ID"]!="g989"]
clean_data
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice in the clean DataFrame.
count_clean_data = clean_data["Mouse ID"].nunique()
count_clean_data
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
#group the data by Drug Regimen
group_data = clean_data.groupby("Drug Regimen")

#Get the mean volume of the tumor 
mean_value = round(group_data["Tumor Volume (mm3)"].mean(),2)

#Get the median volume of the tumor
median_value = round(group_data["Tumor Volume (mm3)"].median(),2)

#Get the variance of the Tumor Volume
var_value = round(group_data["Tumor Volume (mm3)"].var(),2)

#Get the Standard Deviation of the Tumor Volume
std_value = round(group_data["Tumor Volume (mm3)"].std(),2)

#Get the SEM of the Tumor Volume
sem_value = round(group_data["Tumor Volume (mm3)"].sem(),2)

#Created a summary DataFrame to store the result
summary_df = pd.DataFrame({"Mean Value": mean_value,
                          "Median Value": median_value,
                          "Variance": var_value,
                          "Standard Deviation": std_value,
                          "SEM": sem_value})

#Display the Summary Statistics DataFrame
summary_df

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary dataframe.
# Out:
#               Mean Value  Median Value  Variance  Standard Deviation   SEM
# Drug Regimen
# Capomulin          40.68         41.56     24.95                4.99  0.33
# Ceftamin           52.59         51.78     39.29                6.27  0.47
# Infubinol          52.88         51.82     43.13                6.57  0.49
# Ketapril           55.24         53.70     68.55                8.28  0.60
# Naftisol           54.33         52.51     66.17                8.13  0.60
# Placebo            54.03         52.29     61.17                7.82  0.58
# Propriva           52.32         50.45     43.85                6.62  0.54
# Ramicane           40.22         40.67     23.49                4.85  0.32
# Stelasyn           54.23         52.43     59.45                7.71  0.57
# Zoniferol          53.24         51.82     48.53                6.97  0.52

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Using the aggregation method, produce the same summary statistics in a single line
group_data.aggregate(["mean","median", "var","std", "sem"])["Tumor Volume (mm3)"].round(2)
# Out:
#                mean  median    var   std   sem
# Drug Regimen
# Capomulin     40.68   41.56  24.95  4.99  0.33
# Ceftamin      52.59   51.78  39.29  6.27  0.47
# Infubinol     52.88   51.82  43.13  6.57  0.49
# Ketapril      55.24   53.70  68.55  8.28  0.60
# Naftisol      54.33   52.51  66.17  8.13  0.60
# Placebo       54.03   52.29  61.17  7.82  0.58
# Propriva      52.32   50.45  43.85  6.62  0.54
# Ramicane      40.22   40.67  23.49  4.85  0.32
# Stelasyn      54.23   52.43  59.45  7.71  0.57
# Zoniferol     53.24   51.82  48.53  6.97  0.52

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pandas.
bar_chart = group_data["Tumor Volume (mm3)"].count()
bar_chart.plot(kind="bar",ylabel= "Tumor Volume(mm3)",title= "Tumor Volume over Drug Regimen")
plt.ylim(0,250)

# Display the Bar chart
plt.show()

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pyplot.

x_axis = bar_chart.index #Take the value from the chart above done using pandas
y_axis = group_data["Tumor Volume (mm3)"].count() #y-axis values

#Bar Chart using pyplot library
plt.bar(x_axis,y_axis, color ="r",width =0.5)

#Formatting the Bar Chart with labels and title
plt.xticks(rotation=90)
plt.title("Tumor Volume over Drug Regimen")
plt.xlabel("Drug Regimen")
plt.ylabel("Tumor Volume (mm3)")
plt.ylim(0,250)

# Display the Bar chart
plt.show()
plt.tight_layout()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas

#Get the sex value count 
sex_chart= clean_data["Sex"].value_counts()

#Seperate the sex using explode
explode= [0.1,0]
color = ["red","skyblue"]
#Pie chart using pandas
sex_chart.plot(kind="pie",title="Female VS Male",autopct="%1.1f%%",colors=color,shadow=True,explode=explode)
plt.axis("equal")

# Display the pie chart
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot

label=["Male","Female"]
explode=[0.1,0]

#Pie Chart using pyplot Library
plt.pie(sex_chart,labels=label,autopct="%1.1f%%",shadow=True,explode=explode)

#Formatting the pie chart
plt.axis("equal")
plt.title("Female VS Male")

# Display the pie chart
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

#Group the data by Mouse ID
group_mouse = clean_data.groupby("Mouse ID") 

# Start by getting the last (greatest) timepoint for each mouse
group_mouse = group_mouse["Timepoint"].max()

# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
merge_mouse = pd.merge(merge_data,group_mouse, on=["Mouse ID", "Timepoint"])

#Display thr merge DataFrame
merge_mouse.head(20)
# Out:
#    Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0      k403     Ramicane    Male          21          16         45
# 1      s185    Capomulin  Female           3          17         45
# 2      x401    Capomulin  Female          16          15         45
# 3      m601    Capomulin    Male          22          17         45
# 4      g791     Ramicane    Male          11          16         45
# 5      s508     Ramicane    Male           1          17         45
# 6      f966    Capomulin    Male          16          17         20
# 7      m546     Ramicane    Male          18          16         45
# 8      z578     Ramicane    Male          11          16         45
# 9      j913     Ramicane  Female           4          17         45
# 10     u364    Capomulin    Male          18          17         45
# 11     n364     Ramicane    Male           4          17         45
# 12     y793    Capomulin    Male          17          17         45
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels)

#List of four Drugs for calculation...
drug = ["Capomulin", "Infubinol", "Ceftamin","Ramicane"] 

# Create empty list to fill with tumor vol data (for plotting)
tumor_vol = []

# Calculate the IQR and quantitatively determine if there are any potential outliers. 
for d in drug:
    #Locate the drugs in the Drugs Regimen
    treat_df = merge_mouse.loc[merge_mouse["Drug Regimen"] == d]
    
    # Locate the rows which contain mice on each drug and get the tumor volumes
    #Also store the data into the empty list created to store tumor volume data
    tumor_vol.append(treat_df["Tumor Volume (mm3)"])
    
    # Determine outliers using upper and lower bounds
    
    # Get the quartile value
    quartiles = treat_df["Tumor Volume (mm3)"].quantile([.25,.5,.75])
    # Lower Quartile
    lower_q = quartiles[.25]
    # Upper Quartile
    upper_q = quartiles[.75]
    print(f"The Lower quartiles is: {round(lower_q,2)}\n")
    print(f"The Upper quartiles is: {round(upper_q,2)}\n")
    
    # Interquartile Range 
    iqr = upper_q - lower_q
    print(f"The interquartile range is: {round(iqr,2)}\n")
    
    # Lower Bound Value
    lower_bound = lower_q - (1.5 * iqr)
    # Upper Bound Value
    upper_bound = upper_q + (1.5 * iqr)
    print(f"The Lower Bound is: {round(lower_bound,2)}\n")
    print(f"The Upper Bound is: {round(upper_bound,2)}\n")
    
    # Ge the Outliners Value
    outliners = treat_df.loc[(treat_df["Tumor Volume (mm3)"]<lower_bound) | (treat_df["Tumor Volume (mm3)"]>upper_bound)]
    print(f"{d} Potential Outliners: {outliners}")
    print("----------------------------------------------------------------------------------")
# Out:
# The Lower quartiles is: 32.38
#
# The Upper quartiles is: 40.16
#
# The interquartile range is: 7.78
#
# The Lower Bound is: 20.7
#
# The Upper Bound is: 51.83
#
# Capomulin Potential Outliners: Empty DataFrame
# Columns: [Mouse ID, Drug Regimen, Sex, Age_months, Weight (g), Timepoint, Tumor Volume (mm3), Metastatic Sites]
# Index: []
# ----------------------------------------------------------------------------------
# The Lower quartiles is: 54.05
#
# The Upper quartiles is: 65.53
#
# The interquartile range is: 11.48
#
# The Lower Bound is: 36.83
#
# The Upper Bound is: 82.74
#
# Infubinol Potential Outliners:    Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 74     c326    Infubinol  Female          18          25          5
#
#     Tumor Volume (mm3)  Metastatic Sites
# 74           36.321346                 0
# ----------------------------------------------------------------------------------
# The Lower quartiles is: 48.72
#
# ...

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
fig1, ax1 =plt.subplots()

#Give the outliner customize formatting
outliner = dict(markerfacecolor="r",markersize=13)

# Get the boxplot thorugh subplots
ax1.boxplot(tumor_vol,labels= drug,flierprops=outliner)

# Formatting the plot with title and labels
ax1.set_title("Drug Regimen over Final Tumor Volume")
plt.xlabel("Drugs")
plt.ylabel("Tumor Volume (mm3)")

#Display the Box Plot
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Locate a Mouse ID which is treated by Drug Regimen = "Capomulin"
loc_mouse = clean_data.loc[clean_data["Mouse ID"]== "m601" ]
loc_mouse
# Out:
#    Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 30     m601    Capomulin  Male          22          17          0
# 31     m601    Capomulin  Male          22          17          5
# 32     m601    Capomulin  Male          22          17         10
# 33     m601    Capomulin  Male          22          17         15
# 34     m601    Capomulin  Male          22          17         20
# 35     m601    Capomulin  Male          22          17         25
# 36     m601    Capomulin  Male          22          17         30
# 37     m601    Capomulin  Male          22          17         35
# 38     m601    Capomulin  Male          22          17         40
# 39     m601    Capomulin  Male          22          17         45
#
#     Tumor Volume (mm3)  Metastatic Sites
# 30           45.000000                 0
# 31           41.408591                 1
# 32           36.825367                 1
# 33           35.464612                 1
# ...

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin

plt.plot(loc_mouse["Timepoint"],loc_mouse["Tumor Volume (mm3)"],color="r")

#Formatting the line chart with title and labels and limit of both axis
plt.title("Tumor Volume VS Timepoint")
plt.xlabel("Timepoint")
plt.ylabel("Tumor Volume (mm3)")
plt.xlim(0,45)
plt.ylim(28,46)
plt.show()

# %%
# Locate all the data of mouse which are treated by Drug Regimen = "Capomulin"
loc_drug= clean_data.loc[clean_data["Drug Regimen"]== "Capomulin"]
loc_drug
# Out:
#      Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 10       s185    Capomulin  Female           3          17          0
# 11       s185    Capomulin  Female           3          17          5
# 12       s185    Capomulin  Female           3          17         10
# 13       s185    Capomulin  Female           3          17         15
# 14       s185    Capomulin  Female           3          17         20
# ...       ...          ...     ...         ...         ...        ...
# 440      i557    Capomulin  Female           1          24         45
# 1452     r157    Capomulin    Male          22          25          0
# 1453     r157    Capomulin    Male          22          25          5
# 1454     r157    Capomulin    Male          22          25         10
# 1455     r157    Capomulin    Male          22          25         15
#
#       Tumor Volume (mm3)  Metastatic Sites
# 10             45.000000                 0
# ...

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen

# Group the data by Mouse ID for scatter plot
group_avg = loc_drug.groupby(loc_drug["Mouse ID"]).mean()

# Get the scatter plot 
plt.scatter(group_avg["Weight (g)"],group_avg["Tumor Volume (mm3)"],100,marker="+",color="r")

#Formatting the plot with labels and title and limits of both axis
plt.title("Average Tumor Volume VS Mouse Weight")
plt.xlabel("Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")
plt.xlim(14,26)
plt.ylim(33,47)

# Display the Scatter plot
plt.show()
plt.tight_layout()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 

# Get the correlation Coefficient for weight and average tumor volume
correlation = st.pearsonr(group_avg["Weight (g)"], group_avg["Tumor Volume (mm3)"])
print(f"The correlation between both factors is {round(correlation[0],2)}")

# for mouse weight and average tumor volume for the Capomulin regimen
# Use the same groupby data created in the above cell

#Set the x-axis and y-axis for the scatter plot
weight =group_avg["Weight (g)"] # x-axis
tumor = group_avg["Tumor Volume (mm3)"] # y-axis

# variable to calculate the Linear Regression
tumor_slope, tumor_intercept, rvalue, pvalue, std_err = st.linregress(weight,tumor)

# Get the Scatter Plot
plt.scatter(weight,tumor,90 )

#Linear Regression Equation "y = mx + c"
tumor_fit= weight * tumor_slope + tumor_intercept

# Get the rsquared value
print(f"The rsquared Value is: {round(rvalue**2,2)}")

# Get the linear Line on the scatter Plot
plt.plot(weight,tumor_fit,"-",color="r")

# Formatting the scatter plot with title labels and limits of both the axis
plt.title("Aversge Tumor Volume VS Weight")
plt.xlabel("Weight (g)")
plt.ylabel("Tumor Volume (mm3)")
plt.xlim(14,26)
plt.ylim(33,47)

# Display the Scatter Plot with Linear Line
plt.show()
# Out:
# The correlation between both factors is 0.84
# The rsquared Value is: 0.71

# %%
# The Three Observations made from the data are..

print("1. From the Pie Chart we can say the gender selection of the mouse are almost equal to eachother, so that determining the \t effect on the gender can be analyse easily \n")
print("2. The Tumor Volume of the Mouse treated with Capomulin Regimen has been decrease with the increase in Time Point \n")
print("3. From the Scatter Plot we can state that the Tumor Volume(mm3) has increased with the increased in weight(g) of the mouse \t treated with Capomulin Regimen ")
# Out:
# 1. From the Pie Chart we can say the gender selection of the mouse are almost equal to eachother, so that determining the 	 effect on the gender can be analyse easily
#
# 2. The Tumor Volume of the Mouse treated with Capomulin Regimen has been decrease with the increase in Time Point
#
# 3. From the Scatter Plot we can state that the Tumor Volume(mm3) has increased with the increased in weight(g) of the mouse 	 treated with Capomulin Regimen
